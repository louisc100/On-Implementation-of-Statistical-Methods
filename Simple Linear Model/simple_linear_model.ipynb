# %% [markdown]
# # Simple Linear Model
# We will implement the a simple linear model for dataset. Linear model has the following form
# $$Y = \beta_0 + \beta_1 X + \epsilon$$
# where $\epsilon \sim N(0, \sigma^2)$.

# %%
1 + 1
# Out:
# 2
